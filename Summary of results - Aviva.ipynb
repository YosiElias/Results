# %%
#Reading Libraries
import os
import sys
from PIL import Image
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import cv2

# %%
df = pd.DataFrame()

# %%
#Open a jpg file
filename_list = []

filename_1 = r"C:\Users\Aviva\Desktop\EDS\AM50\before\AM50_before\AM50_before01.jpg"
filename_list.append(filename_1)
filename_2 = r"C:\Users\Aviva\Desktop\EDS\AM50\before\AM50_before\AM50_before02.jpg"
filename_list.append(filename_2)
filename_3 = r"C:\Users\Aviva\Desktop\EDS\AM50\before\AM50_before\AM50_before03.jpg"
filename_list.append(filename_3)
filename_4 = r"C:\Users\Aviva\Desktop\EDS\AM50\before\AM50_before\AM50_before04.jpg"
filename_list.append(filename_4)
filename_5 = r"C:\Users\Aviva\Desktop\EDS\AM50\before\AM50_before\AM50_before05.jpg"
filename_list.append(filename_5)
filename_6 = r"C:\Users\Aviva\Desktop\EDS\AM50\before\AM50_before\AM50_before06.jpg"
filename_list.append(filename_6)

filename_7 = r"C:\Users\Aviva\Desktop\EDS\AM50\before\AM50_before\AM50_before07.jpg"
filename_list.append(filename_7)
filename_8 = r"C:\Users\Aviva\Desktop\EDS\AM50\before\AM50_before\AM50_before08.jpg"
filename_list.append(filename_8)
filename_9 = r"C:\Users\Aviva\Desktop\EDS\AM50\before\AM50_before\AM50_before09.jpg"
filename_list.append(filename_9)
filename_10 = r"C:\Users\Aviva\Desktop\EDS\AM50\before\AM50_before\AM50_before10.jpg"
filename_list.append(filename_10)
filename_11 = r"C:\Users\Aviva\Desktop\EDS\AM50\before\AM50_before\AM50_before11.jpg"
filename_list.append(filename_11)
filename_12 = r"C:\Users\Aviva\Desktop\EDS\AM50\before\AM50_before\AM50_before12.jpg"
filename_list.append(filename_12)

filename_13 = r"C:\Users\Aviva\Desktop\EDS\AM50\before\AM50_before\AM50_before13.jpg"
filename_list.append(filename_13)
filename_14 = r"C:\Users\Aviva\Desktop\EDS\AM50\before\AM50_before\AM50_before14.jpg"
filename_list.append(filename_14)
filename_15 = r"C:\Users\Aviva\Desktop\EDS\AM50\before\AM50_before\AM50_before15.jpg"
filename_list.append(filename_15)
filename_16 = r"C:\Users\Aviva\Desktop\EDS\AM50\before\AM50_before\AM50_before16.jpg"
filename_list.append(filename_16)
filename_17 = r"C:\Users\Aviva\Desktop\EDS\AM50\before\AM50_before\AM50_before17.jpg"
filename_list.append(filename_17)
filename_18 = r"C:\Users\Aviva\Desktop\EDS\AM50\before\AM50_before\AM50_before18.jpg"
filename_list.append(filename_18)

filename_19 = r"C:\Users\Aviva\Desktop\EDS\AM50\before\AM50_before\AM50_before19.jpg"
filename_list.append(filename_19)
filename_20 = r"C:\Users\Aviva\Desktop\EDS\AM50\before\AM50_before\AM50_before20.jpg"
filename_list.append(filename_20)
filename_21 = r"C:\Users\Aviva\Desktop\EDS\AM50\before\AM50_before\AM50_before21.jpg"
filename_list.append(filename_21)
filename_22 = r"C:\Users\Aviva\Desktop\EDS\AM50\before\AM50_before\AM50_before22.jpg"
filename_list.append(filename_22)
filename_23 = r"C:\Users\Aviva\Desktop\EDS\AM50\before\AM50_before\AM50_before23.jpg"
filename_list.append(filename_23)
filename_24 = r"C:\Users\Aviva\Desktop\EDS\AM50\before\AM50_before\AM50_before24.jpg"
filename_list.append(filename_24)

    
filename_25 = r"C:\Users\Aviva\Desktop\EDS\AM50\before\AM50_before\AM50_before25.jpg"
filename_list.append(filename_25)
filename_26 = r"C:\Users\Aviva\Desktop\EDS\AM50\before\AM50_before\AM50_before26.jpg"
filename_list.append(filename_26)
filename_27 = r"C:\Users\Aviva\Desktop\EDS\AM50\before\AM50_before\AM50_before27.jpg"
filename_list.append(filename_27)
filename_28 = r"C:\Users\Aviva\Desktop\EDS\AM50\before\AM50_before\AM50_before28.jpg"
filename_list.append(filename_28)
filename_29 = r"C:\Users\Aviva\Desktop\EDS\AM50\before\AM50_before\AM50_before29.jpg"
filename_list.append(filename_29)
filename_30 = r"C:\Users\Aviva\Desktop\EDS\AM50\before\AM50_before\AM50_before30.jpg"
filename_list.append(filename_30)

filename_31 = r"C:\Users\Aviva\Desktop\EDS\AM50\before\AM50_before\AM50_before31.jpg"
filename_list.append(filename_31)
filename_32 = r"C:\Users\Aviva\Desktop\EDS\AM50\before\AM50_before\AM50_before32.jpg"
filename_list.append(filename_32)
filename_33 = r"C:\Users\Aviva\Desktop\EDS\AM50\before\AM50_before\AM50_before33.jpg"
filename_list.append(filename_33)
filename_34 = r"C:\Users\Aviva\Desktop\EDS\AM50\before\AM50_before\AM50_before34.jpg"
filename_list.append(filename_34)
filename_35 = r"C:\Users\Aviva\Desktop\EDS\AM50\before\AM50_before\AM50_before35.jpg"
filename_list.append(filename_35)
filename_36 = r"C:\Users\Aviva\Desktop\EDS\AM50\before\AM50_before\AM50_before36.jpg"
filename_list.append(filename_36)

#filter by area
s1= 0
s2 = 100000000
result= []




for file in filename_list:
    
    gray = cv2.imread(file, 0)
    #threshold
    th, threshed = cv2.threshold(gray, 100, 255,cv2.THRESH_BINARY_INV|cv2.THRESH_OTSU)
    #findcontours
    cnts = cv2.findContours(threshed, cv2.RETR_LIST, cv2.CHAIN_APPROX_SIMPLE)[-2]
    
    xcnts = []
    for cnt in cnts:
        if s1<cv2.contourArea(cnt) <s2:
            xcnts.append(cnt)
    df = df.append({'AM50_before': (len(xcnts))}, ignore_index=True)
#     print("Dots number: {}".format(len(xcnts)))

mean_AM50_40min = df.mean(axis = 0)
#df.to_csv('AM50_40min.csv', index=False)
print(mean_AM50_40min)
df
# Out:
# AM50_before    68.222222
# dtype: float64
#     AM50_before
# 0          69.0
# 1          60.0
# 2          63.0
# 3          69.0
# 4          58.0
# 5          67.0
# 6          59.0
# 7          71.0
# 8          68.0
# 9          61.0
# 10         58.0
# 11         70.0
# 12         70.0
# 13         73.0
# 14         58.0
# 15         80.0
# 16         66.0
# 17         71.0
# 18         67.0
# 19         72.0
# 20         63.0
# 21         72.0
# 22         56.0
# 23         69.0
# 24         69.0
# 25         73.0
# 26         55.0
# 27         67.0
# 28         92.0
# 29         61.0
# 30         88.0
# 31         76.0
# 32         73.0
# 33         95.0
# 34         54.0
# 35         63.0

# %%
#Open a jpg file
filename_list = []

filename_1 = r"C:\Users\Aviva\Desktop\EDS\AM50\Hanks\AM50_hanks\AM50_hanks01.jpg"
filename_list.append(filename_1)
filename_2 = r"C:\Users\Aviva\Desktop\EDS\AM50\Hanks\AM50_hanks\AM50_hanks02.jpg"
filename_list.append(filename_2)
filename_3 = r"C:\Users\Aviva\Desktop\EDS\AM50\Hanks\AM50_hanks\AM50_hanks03.jpg"
filename_list.append(filename_3)
filename_4 = r"C:\Users\Aviva\Desktop\EDS\AM50\Hanks\AM50_hanks\AM50_hanks04.jpg"
filename_list.append(filename_4)
filename_5 = r"C:\Users\Aviva\Desktop\EDS\AM50\Hanks\AM50_hanks\AM50_hanks05.jpg"
filename_list.append(filename_5)
filename_6 = r"C:\Users\Aviva\Desktop\EDS\AM50\before\Hanks\AM50_hanks\AM50_hanks06.jpg"
filename_list.append(filename_6)

filename_7 = r"C:\Users\Aviva\Desktop\EDS\AM50\Hanks\AM50_hanks\AM50_hanks07.jpg"
filename_list.append(filename_7)
filename_8 = r"C:\Users\Aviva\Desktop\EDS\AM50\Hanks\AM50_hanks\AM50_hanks08.jpg"
filename_list.append(filename_8)
filename_9 = r"C:\Users\Aviva\Desktop\EDS\AM50\Hanks\AM50_hanks\AM50_hanks09.jpg"
filename_list.append(filename_9)
filename_10 = r"C:\Users\Aviva\Desktop\EDS\AM50\Hanks\AM50_hanks\AM50_hanks10.jpg"
filename_list.append(filename_10)
filename_11 = r"C:\Users\Aviva\Desktop\EDS\AM50\Hanks\AM50_hanks\AM50_hanks11.jpg"
filename_list.append(filename_11)
filename_12 = r"C:\Users\Aviva\Desktop\EDS\AM50\Hanks\AM50_hanks\AM50_hanks12.jpg"
filename_list.append(filename_12)

filename_13 = r"C:\Users\Aviva\Desktop\EDS\AM50\Hanks\AM50_hanks\AM50_hanks13.jpg"
filename_list.append(filename_13)
filename_14 = r"C:\Users\Aviva\Desktop\EDS\AM50\Hanks\AM50_hanks\AM50_hanks14.jpg"
filename_list.append(filename_14)
filename_15 = r"C:\Users\Aviva\Desktop\EDS\AM50\Hanks\AM50_hanks\AM50_hanks15.jpg"
filename_list.append(filename_15)
filename_16 = r"C:\Users\Aviva\Desktop\EDS\AM50\Hanks\AM50_hanks\AM50_hanks16.jpg"
filename_list.append(filename_16)
filename_17 = r"C:\Users\Aviva\Desktop\EDS\AM50\Hanks\AM50_hanks\AM50_hanks17.jpg"
filename_list.append(filename_17)
filename_18 = r"C:\Users\Aviva\Desktop\EDS\AM50\Hanks\AM50_hanks\AM50_hanks18.jpg"
filename_list.append(filename_18)

filename_19 = r"C:\Users\Aviva\Desktop\EDS\AM50\Hanks\AM50_hanks\AM50_hanks19.jpg"
filename_list.append(filename_19)
filename_20 = r"C:\Users\Aviva\Desktop\EDS\AM50\Hanks\AM50_hanks\AM50_hanks20.jpg"
filename_list.append(filename_20)
filename_21 = r"C:\Users\Aviva\Desktop\EDS\AM50\Hanks\AM50_hanks\AM50_hanks21.jpg"
filename_list.append(filename_21)
filename_22 = r"C:\Users\Aviva\Desktop\EDS\AM50\Hanks\AM50_hanks\AM50_hanks22.jpg"
filename_list.append(filename_22)
filename_23 = r"C:\Users\Aviva\Desktop\EDS\AM50\Hanks\AM50_hanks\AM50_hanks23.jpg"
filename_list.append(filename_23)
filename_24 = r"C:\Users\Aviva\Desktop\EDS\AM50\Hanks\AM50_hanks\AM50_hanks24.jpg"
filename_list.append(filename_24)

    
filename_25 = r"C:\Users\Aviva\Desktop\EDS\AM50\Hanks\AM50_hanks\AM50_hanks25.jpg"
filename_list.append(filename_25)
filename_26 = r"C:\Users\Aviva\Desktop\EDS\AM50\Hanks\AM50_hanks\AM50_hanks26.jpg"
filename_list.append(filename_26)
filename_27 = r"C:\Users\Aviva\Desktop\EDS\AM50\Hanks\AM50_hanks\AM50_hanks27.jpg"
filename_list.append(filename_27)
filename_28 = r"C:\Users\Aviva\Desktop\EDS\AM50\Hanks\AM50_hanks\AM50_hanks28.jpg"
filename_list.append(filename_28)
filename_29 = r"C:\Users\Aviva\Desktop\EDS\AM50\Hanks\AM50_hanks\AM50_hanks29.jpg"
filename_list.append(filename_29)
filename_30 = r"C:\Users\Aviva\Desktop\EDS\AM50\Hanks\AM50_hanks\AM50_hanks30.jpg"
filename_list.append(filename_30)

filename_31 = r"C:\Users\Aviva\Desktop\EDS\AM50\Hanks\AM50_hanks\AM50_hanks31.jpg"
filename_list.append(filename_31)
filename_32 = r"C:\Users\Aviva\Desktop\EDS\AM50\Hanks\AM50_hanks\AM50_hanks32.jpg"
filename_list.append(filename_32)
filename_33 = r"C:\Users\Aviva\Desktop\EDS\AM50\Hanks\AM50_hanks\AM50_hanks33.jpg"
filename_list.append(filename_33)
filename_34 = r"C:\Users\Aviva\Desktop\EDS\AM50\Hanks\AM50_hanks\AM50_hanks34.jpg"
filename_list.append(filename_34)
filename_35 = r"C:\Users\Aviva\Desktop\EDS\AM50\Hanks\AM50_hanks\AM50_hanks35.jpg"
filename_list.append(filename_35)
filename_36 = r"C:\Users\Aviva\Desktop\EDS\AM50\Hanks\AM50_hanks\AM50_hanks36.jpg"
filename_list.append(filename_36)

#filter by area
s1= 0
s2 = 100000000
result= []




for file in filename_list:
    
    gray = cv2.imread(file, 0)
    #threshold
    th, threshed = cv2.threshold(gray, 100, 255,cv2.THRESH_BINARY_INV|cv2.THRESH_OTSU)
    #findcontours
    cnts = cv2.findContours(threshed, cv2.RETR_LIST, cv2.CHAIN_APPROX_SIMPLE)[-2]
    
    xcnts = []
    for cnt in cnts:
        if s1<cv2.contourArea(cnt) <s2:
            xcnts.append(cnt)
    result.append(len(xcnts))
#     print("Dots number: {}".format(len(xcnts)))


dataSei = pd.Series(data=result)
df['AM50_Hanks']=dataSei
#df.to_csv('AM50_40min.csv', index=False)
df
# Out:
#     AM50_before  AM50_Hanks
# 0          69.0          68
# 1          60.0          78
# 2          63.0          76
# 3          69.0          60
# 4          58.0          88
# 5          67.0           0
# 6          59.0          73
# 7          71.0          69
# 8          68.0          86
# 9          61.0          89
# 10         58.0          84
# 11         70.0          77
# 12         70.0         103
# 13         73.0          84
# 14         58.0          88
# 15         80.0          84
# 16         66.0          89
# 17         71.0         101
# 18         67.0          99
# 19         72.0         109
# 20         63.0          89
# 21         72.0          85
# 22         56.0         106
# 23         69.0         101
# 24         69.0          94
# 25         73.0          92
# 26         55.0          85
# 27         67.0          99
# 28         92.0         100
# 29         61.0          96
# 30         88.0          81
# 31         76.0          81
# ...

# %%
#Open a jpg file
filename_list = []

filename_1 = r"C:\Users\Aviva\Desktop\EDS\AM50\NaCl\AM50_NaCl\AM50_NaCl01.jpg"
filename_list.append(filename_1)
filename_2 = r"C:\Users\Aviva\Desktop\EDS\AM50\NaCl\AM50_NaCl\AM50_NaCl02.jpg"
filename_list.append(filename_2)
filename_3 = r"C:\Users\Aviva\Desktop\EDS\AM50\NaCl\AM50_NaCl\AM50_NaCl03.jpg"
filename_list.append(filename_3)
filename_4 = r"C:\Users\Aviva\Desktop\EDS\AM50\NaCl\AM50_NaCl\AM50_NaCl04.jpg"
filename_list.append(filename_4)
filename_5 = r"C:\Users\Aviva\Desktop\EDS\AM50\NaCl\AM50_NaCl\AM50_NaCl05.jpg"
filename_list.append(filename_5)
filename_6 = r"C:\Users\Aviva\Desktop\EDS\AM50\NaCl\AM50_NaCl\AM50_NaCl06.jpg"
filename_list.append(filename_6)

filename_7 = r"C:\Users\Aviva\Desktop\EDS\AM50\NaCl\AM50_NaCl\AM50_NaCl07.jpg"
filename_list.append(filename_7)
filename_8 = r"C:\Users\Aviva\Desktop\EDS\AM50\NaCl\AM50_NaCl\AM50_NaCl08.jpg"
filename_list.append(filename_8)
filename_9 = r"C:\Users\Aviva\Desktop\EDS\AM50\NaCl\AM50_NaCl\AM50_NaCl09.jpg"
filename_list.append(filename_9)
filename_10 = r"C:\Users\Aviva\Desktop\EDS\AM50\NaCl\AM50_NaCl\AM50_NaCl10.jpg"
filename_list.append(filename_10)
filename_11 = r"C:\Users\Aviva\Desktop\EDS\AM50\NaCl\AM50_NaCl\AM50_NaCl11.jpg"
filename_list.append(filename_11)
filename_12 = r"C:\Users\Aviva\Desktop\EDS\AM50\NaCl\AM50_NaCl\AM50_NaCl12.jpg"
filename_list.append(filename_12)

filename_13 = r"C:\Users\Aviva\Desktop\EDS\AM50\NaCl\AM50_NaCl\AM50_NaCl13.jpg"
filename_list.append(filename_13)
filename_14 = r"C:\Users\Aviva\Desktop\EDS\AM50\NaCl\AM50_NaCl\AM50_NaCl14.jpg"
filename_list.append(filename_14)
filename_15 = r"C:\Users\Aviva\Desktop\EDS\AM50\NaCl\AM50_NaCl\AM50_NaCl15.jpg"
filename_list.append(filename_15)
filename_16 = r"C:\Users\Aviva\Desktop\EDS\AM50\NaCl\AM50_NaCl\AM50_NaCl16.jpg"
filename_list.append(filename_16)
filename_17 = r"C:\Users\Aviva\Desktop\EDS\AM50\NaCl\AM50_NaCl\AM50_NaCl17.jpg"
filename_list.append(filename_17)
filename_18 = r"C:\Users\Aviva\Desktop\EDS\AM50\NaCl\AM50_NaCl\AM50_NaCl18.jpg"
filename_list.append(filename_18)

filename_19 = r"C:\Users\Aviva\Desktop\EDS\AM50\NaCl\AM50_NaCl\AM50_NaCl19.jpg"
filename_list.append(filename_19)
filename_20 = r"C:\Users\Aviva\Desktop\EDS\AM50\NaCl\AM50_NaCl\AM50_NaCl20.jpg"
filename_list.append(filename_20)
filename_21 = r"C:\Users\Aviva\Desktop\EDS\AM50\NaCl\AM50_NaCl\AM50_NaCl21.jpg"
filename_list.append(filename_21)
filename_22 = r"C:\Users\Aviva\Desktop\EDS\AM50\NaCl\AM50_NaCl\AM50_NaCl22.jpg"
filename_list.append(filename_22)
filename_23 = r"C:\Users\Aviva\Desktop\EDS\AM50\NaCl\AM50_NaCl\AM50_NaCl23.jpg"
filename_list.append(filename_23)
filename_24 = r"C:\Users\Aviva\Desktop\EDS\AM50\NaCl\AM50_NaCl\AM50_NaCl24.jpg"
filename_list.append(filename_24)

    
filename_25 = r"C:\Users\Aviva\Desktop\EDS\AM50\NaCl\AM50_NaCl\AM50_NaCl25.jpg"
filename_list.append(filename_25)
filename_26 = r"C:\Users\Aviva\Desktop\EDS\AM50\NaCl\AM50_NaCl\AM50_NaCl26.jpg"
filename_list.append(filename_26)
filename_27 = r"C:\Users\Aviva\Desktop\EDS\AM50\NaCl\AM50_NaCl\AM50_NaCl27.jpg"
filename_list.append(filename_27)
filename_28 = r"C:\Users\Aviva\Desktop\EDS\AM50\NaCl\AM50_NaCl\AM50_NaCl28.jpg"
filename_list.append(filename_28)
filename_29 = r"C:\Users\Aviva\Desktop\EDS\AM50\NaCl\AM50_NaCl\AM50_NaCl29.jpg"
filename_list.append(filename_29)
filename_30 = r"C:\Users\Aviva\Desktop\EDS\AM50\NaCl\AM50_NaCl\AM50_NaCl30.jpg"
filename_list.append(filename_30)

filename_31 = r"C:\Users\Aviva\Desktop\EDS\AM50\NaCl\AM50_NaCl\AM50_NaCl31.jpg"
filename_list.append(filename_31)
filename_32 = r"C:\Users\Aviva\Desktop\EDS\AM50\NaCl\AM50_NaCl\AM50_NaCl32.jpg"
filename_list.append(filename_32)
filename_33 = r"C:\Users\Aviva\Desktop\EDS\AM50\NaCl\AM50_NaCl\AM50_NaCl33.jpg"
filename_list.append(filename_33)
filename_34 = r"C:\Users\Aviva\Desktop\EDS\AM50\NaCl\AM50_NaCl\AM50_NaCl34.jpg"
filename_list.append(filename_34)
filename_35 = r"C:\Users\Aviva\Desktop\EDS\AM50\NaCl\AM50_NaCl\AM50_NaCl35.jpg"
filename_list.append(filename_35)
filename_36 = r"C:\Users\Aviva\Desktop\EDS\AM50\NaCl\AM50_NaCl\AM50_NaCl36.jpg"
filename_list.append(filename_36)

# %%
#filter by area
s1= 0
s2 = 100000000
result= []



for file in filename_list:
    
    gray = cv2.imread(file, 0)
    #threshold
    th, threshed = cv2.threshold(gray, 100, 255,cv2.THRESH_BINARY_INV|cv2.THRESH_OTSU)
    #findcontours
    cnts = cv2.findContours(threshed, cv2.RETR_LIST, cv2.CHAIN_APPROX_SIMPLE)[-2]
    
    xcnts = []
    for cnt in cnts:
        if s1<cv2.contourArea(cnt) <s2:
            xcnts.append(cnt)
    result.append(len(xcnts))
#     print("Dots number: {}".format(len(xcnts)))

dataSei = pd.Series(data=result)
df['AM50_NaCl']=dataSei


#df.to_csv('AM50_40min.csv', index=False)
df
# Out:
#     AM50_before  AM50_Hanks  AM50_NaCl
# 0          69.0          68         85
# 1          60.0          78         76
# 2          63.0          76         82
# 3          69.0          60         86
# 4          58.0          88         98
# 5          67.0           0         97
# 6          59.0          73        104
# 7          71.0          69         98
# 8          68.0          86        107
# 9          61.0          89        126
# 10         58.0          84         88
# 11         70.0          77         89
# 12         70.0         103         98
# 13         73.0          84        103
# 14         58.0          88        106
# 15         80.0          84        105
# 16         66.0          89        116
# 17         71.0         101        119
# 18         67.0          99        130
# 19         72.0         109        123
# 20         63.0          89        126
# 21         72.0          85        116
# 22         56.0         106        112
# ...

# %%
#Open a jpg file
filename_list = []

filename_1 = r"C:\Users\Aviva\Desktop\EDS\AZ91\before\AZ91_before\AZ91_before01.jpg"
filename_list.append(filename_1)
filename_2 = r"C:\Users\Aviva\Desktop\EDS\AZ91\before\AZ91_before\AZ91_before02.jpg"
filename_list.append(filename_2)
filename_3 = r"C:\Users\Aviva\Desktop\EDS\AZ91\before\AZ91_before\AZ91_before03.jpg"
filename_list.append(filename_3)
filename_4 = r"C:\Users\Aviva\Desktop\EDS\AZ91\before\AZ91_before\AZ91_before04.jpg"
filename_list.append(filename_4)
filename_5 = r"C:\Users\Aviva\Desktop\EDS\AZ91\before\AZ91_before\AZ91_before05.jpg"
filename_list.append(filename_5)
filename_6 = r"C:\Users\Aviva\Desktop\EDS\AZ91\before\AZ91_before\AZ91_before06.jpg"
filename_list.append(filename_6)

filename_7 = r"C:\Users\Aviva\Desktop\EDS\AZ91\before\AZ91_before\AZ91_before07.jpg"
filename_list.append(filename_7)
filename_8 = r"C:\Users\Aviva\Desktop\EDS\AZ91\before\AZ91_before\AZ91_before08.jpg"
filename_list.append(filename_8)
filename_9 = r"C:\Users\Aviva\Desktop\EDS\AZ91\before\AZ91_before\AZ91_before09.jpg"
filename_list.append(filename_9)
filename_10 = r"C:\Users\Aviva\Desktop\EDS\AZ91\before\AZ91_before\AZ91_before10.jpg"
filename_list.append(filename_10)
filename_11 = r"C:\Users\Aviva\Desktop\EDS\AZ91\before\AZ91_before\AZ91_before11.jpg"
filename_list.append(filename_11)
filename_12 = r"C:\Users\Aviva\Desktop\EDS\AZ91\before\AZ91_before\AZ91_before12.jpg"
filename_list.append(filename_12)

filename_13 = r"C:\Users\Aviva\Desktop\EDS\AZ91\before\AZ91_before\AZ91_before13.jpg"
filename_list.append(filename_13)
filename_14 = r"C:\Users\Aviva\Desktop\EDS\AZ91\before\AZ91_before\AZ91_before14.jpg"
filename_list.append(filename_14)
filename_15 = r"C:\Users\Aviva\Desktop\EDS\AZ91\before\AZ91_before\AZ91_before15.jpg"
filename_list.append(filename_15)
filename_16 = r"C:\Users\Aviva\Desktop\EDS\AZ91\before\AZ91_before\AZ91_before16.jpg"
filename_list.append(filename_16)
filename_17 = r"C:\Users\Aviva\Desktop\EDS\AZ91\before\AZ91_before\AZ91_before17.jpg"
filename_list.append(filename_17)
filename_18 = r"C:\Users\Aviva\Desktop\EDS\AZ91\before\AZ91_before\AZ91_before18.jpg"
filename_list.append(filename_18)

filename_19 = r"C:\Users\Aviva\Desktop\EDS\AZ91\before\AZ91_before\AZ91_before19.jpg"
filename_list.append(filename_19)
filename_20 = r"C:\Users\Aviva\Desktop\EDS\AZ91\before\AZ91_before\AZ91_before20.jpg"
filename_list.append(filename_20)
filename_21 = r"C:\Users\Aviva\Desktop\EDS\AZ91\before\AZ91_before\AZ91_before21.jpg"
filename_list.append(filename_21)
filename_22 = r"C:\Users\Aviva\Desktop\EDS\AZ91\before\AZ91_before\AZ91_before22.jpg"
filename_list.append(filename_22)
filename_23 = r"C:\Users\Aviva\Desktop\EDS\AZ91\before\AZ91_before\AZ91_before23.jpg"
filename_list.append(filename_23)
filename_24 = r"C:\Users\Aviva\Desktop\EDS\AZ91\before\AZ91_before\AZ91_before24.jpg"
filename_list.append(filename_24)

    
filename_25 = r"C:\Users\Aviva\Desktop\EDS\AZ91\before\AZ91_before\AZ91_before25.jpg"
filename_list.append(filename_25)
filename_26 = r"C:\Users\Aviva\Desktop\EDS\AZ91\before\AZ91_before\AZ91_before26.jpg"
filename_list.append(filename_26)
filename_27 = r"C:\Users\Aviva\Desktop\EDS\AZ91\before\AZ91_before\AZ91_before27.jpg"
filename_list.append(filename_27)
filename_28 = r"C:\Users\Aviva\Desktop\EDS\AZ91\before\AZ91_before\AZ91_before28.jpg"
filename_list.append(filename_28)
filename_29 = r"C:\Users\Aviva\Desktop\EDS\AZ91\before\AZ91_before\AZ91_before29.jpg"
filename_list.append(filename_29)
filename_30 = r"C:\Users\Aviva\Desktop\EDS\AZ91\before\AZ91_before\AZ91_before30.jpg"
filename_list.append(filename_30)

filename_31 = r"C:\Users\Aviva\Desktop\EDS\AZ91\before\AZ91_before\AZ91_before31.jpg"
filename_list.append(filename_31)
filename_32 = r"C:\Users\Aviva\Desktop\EDS\AZ91\before\AZ91_before\AZ91_before32.jpg"
filename_list.append(filename_32)
filename_33 = r"C:\Users\Aviva\Desktop\EDS\AZ91\before\AZ91_before\AZ91_before33.jpg"
filename_list.append(filename_33)
filename_34 = r"C:\Users\Aviva\Desktop\EDS\AZ91\before\AZ91_before\AZ91_before34.jpg"
filename_list.append(filename_34)
filename_35 = r"C:\Users\Aviva\Desktop\EDS\AZ91\before\AZ91_before\AZ91_before35.jpg"
filename_list.append(filename_35)
filename_36 = r"C:\Users\Aviva\Desktop\EDS\AZ91\before\AZ91_before\AZ91_before36.jpg"
filename_list.append(filename_36)

# %%
#filter by area
s1= 0
s2 = 100000000
result= []



for file in filename_list:
    
    gray = cv2.imread(file, 0)
    #threshold
    th, threshed = cv2.threshold(gray, 100, 255,cv2.THRESH_BINARY_INV|cv2.THRESH_OTSU)
    #findcontours
    cnts = cv2.findContours(threshed, cv2.RETR_LIST, cv2.CHAIN_APPROX_SIMPLE)[-2]

    xcnts = []
    for cnt in cnts:
        if s1<cv2.contourArea(cnt) <s2:
            xcnts.append(cnt)
    result.append(len(xcnts))
#     print("Dots number: {}".format(len(xcnts)))

dataSei = pd.Series(data=result)
df['AZ91_before']=dataSei


#df.to_csv('AM50_40min.csv', index=False)
df
# Out:
#     AM50_before  AM50_Hanks  AM50_NaCl  AZ91_before
# 0          69.0          68         85           52
# 1          60.0          78         76           58
# 2          63.0          76         82           63
# 3          69.0          60         86           64
# 4          58.0          88         98           56
# 5          67.0           0         97           63
# 6          59.0          73        104           57
# 7          71.0          69         98           62
# 8          68.0          86        107           68
# 9          61.0          89        126           62
# 10         58.0          84         88           59
# 11         70.0          77         89           61
# 12         70.0         103         98           72
# 13         73.0          84        103           74
# 14         58.0          88        106           55
# 15         80.0          84        105           72
# 16         66.0          89        116           51
# ...

# %%
#Open a jpg file
filename_list = []

filename_1 = r"C:\Users\Aviva\Desktop\EDS\AZ91\Hanks\AZ91_hanks\AZ91_hanks01.jpg"
filename_list.append(filename_1)
filename_2 = r"C:\Users\Aviva\Desktop\EDS\AZ91\Hanks\AZ91_hanks\AZ91_hanks02.jpg"
filename_list.append(filename_2)
filename_3 = r"C:\Users\Aviva\Desktop\EDS\AZ91\Hanks\AZ91_hanks\AZ91_hanks03.jpg"
filename_list.append(filename_3)
filename_4 = r"C:\Users\Aviva\Desktop\EDS\AZ91\Hanks\AZ91_hanks\AZ91_hanks04.jpg"
filename_list.append(filename_4)
filename_5 = r"C:\Users\Aviva\Desktop\EDS\AZ91\Hanks\AZ91_hanks\AZ91_hanks05.jpg"
filename_list.append(filename_5)
filename_6 = r"C:\Users\Aviva\Desktop\EDS\AZ91\Hanks\AZ91_hanks\AZ91_hanks06.jpg"
filename_list.append(filename_6)

filename_7 = r"C:\Users\Aviva\Desktop\EDS\AZ91\Hanks\AZ91_hanks\AZ91_hanks07.jpg"
filename_list.append(filename_7)
filename_8 = r"C:\Users\Aviva\Desktop\EDS\AZ91\Hanks\AZ91_hanks\AZ91_hanks08.jpg"
filename_list.append(filename_8)
filename_9 = r"C:\Users\Aviva\Desktop\EDS\AZ91\Hanks\AZ91_hanks\AZ91_hanks09.jpg"
filename_list.append(filename_9)
filename_10 = r"C:\Users\Aviva\Desktop\EDS\AZ91\Hanks\AZ91_hanks\AZ91_hanks10.jpg"
filename_list.append(filename_10)
filename_11 = r"C:\Users\Aviva\Desktop\EDS\AZ91\Hanks\AZ91_hanks\AZ91_hanks11.jpg"
filename_list.append(filename_11)
filename_12 = r"C:\Users\Aviva\Desktop\EDS\AZ91\Hanks\AZ91_hanks\AZ91_hanks12.jpg"
filename_list.append(filename_12)

filename_13 = r"C:\Users\Aviva\Desktop\EDS\AZ91\Hanks\AZ91_hanks\AZ91_hanks13.jpg"
filename_list.append(filename_13)
filename_14 = r"C:\Users\Aviva\Desktop\EDS\AZ91\Hanks\AZ91_hanks\AZ91_hanks14.jpg"
filename_list.append(filename_14)
filename_15 = r"C:\Users\Aviva\Desktop\EDS\AZ91\Hanks\AZ91_hanks\AZ91_hanks15.jpg"
filename_list.append(filename_15)
filename_16 = r"C:\Users\Aviva\Desktop\EDS\AZ91\Hanks\AZ91_hanks\AZ91_hanks16.jpg"
filename_list.append(filename_16)
filename_17 = r"C:\Users\Aviva\Desktop\EDS\AZ91\Hanks\AZ91_hanks\AZ91_hanks17.jpg"
filename_list.append(filename_17)
filename_18 = r"C:\Users\Aviva\Desktop\EDS\AZ91\Hanks\AZ91_hanks\AZ91_hanks18.jpg"
filename_list.append(filename_18)

filename_19 = r"C:\Users\Aviva\Desktop\EDS\AZ91\Hanks\AZ91_hanks\AZ91_hanks19.jpg"
filename_list.append(filename_19)
filename_20 = r"C:\Users\Aviva\Desktop\EDS\AZ91\Hanks\AZ91_hanks\AZ91_hanks20.jpg"
filename_list.append(filename_20)
filename_21 = r"C:\Users\Aviva\Desktop\EDS\AZ91\Hanks\AZ91_hanks\AZ91_hanks21.jpg"
filename_list.append(filename_21)
filename_22 = r"C:\Users\Aviva\Desktop\EDS\AZ91\Hanks\AZ91_hanks\AZ91_hanks22.jpg"
filename_list.append(filename_22)
filename_23 = r"C:\Users\Aviva\Desktop\EDS\AZ91\Hanks\AZ91_hanks\AZ91_hanks23.jpg"
filename_list.append(filename_23)
filename_24 = r"C:\Users\Aviva\Desktop\EDS\AZ91\Hanks\AZ91_hanks\AZ91_hanks24.jpg"
filename_list.append(filename_24)

    
filename_25 = r"C:\Users\Aviva\Desktop\EDS\AZ91\Hanks\AZ91_hanks\AZ91_hanks25.jpg"
filename_list.append(filename_25)
filename_26 = r"C:\Users\Aviva\Desktop\EDS\AZ91\Hanks\AZ91_hanks\AZ91_hanks26.jpg"
filename_list.append(filename_26)
filename_27 = r"C:\Users\Aviva\Desktop\EDS\AZ91\Hanks\AZ91_hanks\AZ91_hanks27.jpg"
filename_list.append(filename_27)
filename_28 = r"C:\Users\Aviva\Desktop\EDS\AZ91\Hanks\AZ91_hanks\AZ91_hanks28.jpg"
filename_list.append(filename_28)
filename_29 = r"C:\Users\Aviva\Desktop\EDS\AZ91\Hanks\AZ91_hanks\AZ91_hanks29.jpg"
filename_list.append(filename_29)
filename_30 = r"C:\Users\Aviva\Desktop\EDS\AZ91\Hanks\AZ91_hanks\AZ91_hanks30.jpg"
filename_list.append(filename_30)

filename_31 = r"C:\Users\Aviva\Desktop\EDS\AZ91\Hanks\AZ91_hanks\AZ91_hanks31.jpg"
filename_list.append(filename_31)
filename_32 = r"C:\Users\Aviva\Desktop\EDS\AZ91\Hanks\AZ91_hanks\AZ91_hanks32.jpg"
filename_list.append(filename_32)
filename_33 = r"C:\Users\Aviva\Desktop\EDS\AZ91\Hanks\AZ91_hanks\AZ91_hanks33.jpg"
filename_list.append(filename_33)
filename_34 = r"C:\Users\Aviva\Desktop\EDS\AZ91\Hanks\AZ91_hanks\AZ91_hanks34.jpg"
filename_list.append(filename_34)
filename_35 = r"C:\Users\Aviva\Desktop\EDS\AZ91\Hanks\AZ91_hanks\AZ91_hanks35.jpg"
filename_list.append(filename_35)
filename_36 = r"C:\Users\Aviva\Desktop\EDS\AZ91\Hanks\AZ91_hanks\AZ91_hanks36.jpg"
filename_list.append(filename_36)

# %%
#filter by area
s1= 0
s2 = 100000000
xcnts = []
result= []



for file in filename_list:
    
    gray = cv2.imread(file, 0)
    #threshold
    th, threshed = cv2.threshold(gray, 100, 255,cv2.THRESH_BINARY_INV|cv2.THRESH_OTSU)
    #findcontours
    cnts = cv2.findContours(threshed, cv2.RETR_LIST, cv2.CHAIN_APPROX_SIMPLE)[-2]
   
    xcnts = []
    for cnt in cnts:
        if s1<cv2.contourArea(cnt) <s2:
            xcnts.append(cnt)
    result.append(len(xcnts))
#     print("Dots number: {}".format(len(xcnts)))

dataSei = pd.Series(data=result)
df['AZ91_hanks']=dataSei


#df.to_csv('AM50_40min.csv', index=False)
df
# Out:
#     AM50_before  AM50_Hanks  AM50_NaCl  AZ91_before  AZ91_hanks
# 0          69.0          68         85           52          81
# 1          60.0          78         76           58         112
# 2          63.0          76         82           63         107
# 3          69.0          60         86           64          98
# 4          58.0          88         98           56         107
# 5          67.0           0         97           63         106
# 6          59.0          73        104           57         101
# 7          71.0          69         98           62         108
# 8          68.0          86        107           68         108
# 9          61.0          89        126           62         117
# 10         58.0          84         88           59         110
# 11         70.0          77         89           61         111
# 12         70.0         103         98           72         119
# 13         73.0          84        103           74         118
# ...

# %%
#Open a jpg file
filename_list = []

filename_1 = r"C:\Users\Aviva\Desktop\EDS\AZ91\NaCl\AZ91_NaCl\AZ91_NaCl01.jpg"
filename_list.append(filename_1)
filename_2 = r"C:\Users\Aviva\Desktop\EDS\AZ91\NaCl\AZ91_NaCl\AZ91_NaCl02.jpg"
filename_list.append(filename_2)
filename_3 = r"C:\Users\Aviva\Desktop\EDS\AZ91\NaCl\AZ91_NaCl\AZ91_NaCl03.jpg"
filename_list.append(filename_3)
filename_4 = r"C:\Users\Aviva\Desktop\EDS\AZ91\NaCl\AZ91_NaCl\AZ91_NaCl04.jpg"
filename_list.append(filename_4)
filename_5 = r"C:\Users\Aviva\Desktop\EDS\AZ91\NaCl\AZ91_NaCl\AZ91_NaCl05.jpg"
filename_list.append(filename_5)
filename_6 = r"C:\Users\Aviva\Desktop\EDS\AZ91\NaCl\AZ91_NaCl\AZ91_NaCl06.jpg"
filename_list.append(filename_6)

filename_7 = r"C:\Users\Aviva\Desktop\EDS\AZ91\NaCl\AZ91_NaCl\AZ91_NaCl07.jpg"
filename_list.append(filename_7)
filename_8 = r"C:\Users\Aviva\Desktop\EDS\AZ91\NaCl\AZ91_NaCl\AZ91_NaCl08.jpg"
filename_list.append(filename_8)
filename_9 = r"C:\Users\Aviva\Desktop\EDS\AZ91\NaCl\AZ91_NaCl\AZ91_NaCl09.jpg"
filename_list.append(filename_9)
filename_10 = r"C:\Users\Aviva\Desktop\EDS\AZ91\NaCl\AZ91_NaCl\AZ91_NaCl10.jpg"
filename_list.append(filename_10)
filename_11 = r"C:\Users\Aviva\Desktop\EDS\AZ91\NaCl\AZ91_NaCl\AZ91_NaCl11.jpg"
filename_list.append(filename_11)
filename_12 = r"C:\Users\Aviva\Desktop\EDS\AZ91\NaCl\AZ91_NaCl\AZ91_NaCl12.jpg"
filename_list.append(filename_12)

filename_13 = r"C:\Users\Aviva\Desktop\EDS\AZ91\NaCl\AZ91_NaCl\AZ91_NaCl13.jpg"
filename_list.append(filename_13)
filename_14 = r"C:\Users\Aviva\Desktop\EDS\AZ91\NaCl\AZ91_NaCl\AZ91_NaCl14.jpg"
filename_list.append(filename_14)
filename_15 = r"C:\Users\Aviva\Desktop\EDS\AZ91\NaCl\AZ91_NaCl\AZ91_NaCl15.jpg"
filename_list.append(filename_15)
filename_16 = r"C:\Users\Aviva\Desktop\EDS\AZ91\NaCl\AZ91_NaCl\AZ91_NaCl16.jpg"
filename_list.append(filename_16)
filename_17 = r"C:\Users\Aviva\Desktop\EDS\AZ91\NaCl\AZ91_NaCl\AZ91_NaCl17.jpg"
filename_list.append(filename_17)
filename_18 = r"C:\Users\Aviva\Desktop\EDS\AZ91\NaCl\AZ91_NaCl\AZ91_NaCl18.jpg"
filename_list.append(filename_18)

filename_19 = r"C:\Users\Aviva\Desktop\EDS\AZ91\NaCl\AZ91_NaCl\AZ91_NaCl19.jpg"
filename_list.append(filename_19)
filename_20 = r"C:\Users\Aviva\Desktop\EDS\AZ91\NaCl\AZ91_NaCl\AZ91_NaCl20.jpg"
filename_list.append(filename_20)
filename_21 = r"C:\Users\Aviva\Desktop\EDS\AZ91\NaCl\AZ91_NaCl\AZ91_NaCl21.jpg"
filename_list.append(filename_21)
filename_22 = r"C:\Users\Aviva\Desktop\EDS\AZ91\NaCl\AZ91_NaCl\AZ91_NaCl22.jpg"
filename_list.append(filename_22)
filename_23 = r"C:\Users\Aviva\Desktop\EDS\AZ91\NaCl\AZ91_NaCl\AZ91_NaCl23.jpg"
filename_list.append(filename_23)
filename_24 = r"C:\Users\Aviva\Desktop\EDS\AZ91\NaCl\AZ91_NaCl\AZ91_NaCl24.jpg"
filename_list.append(filename_24)

    
filename_25 = r"C:\Users\Aviva\Desktop\EDS\AZ91\NaCl\AZ91_NaCl\AZ91_NaCl25.jpg"
filename_list.append(filename_25)
filename_26 = r"C:\Users\Aviva\Desktop\EDS\AZ91\NaCl\AZ91_NaCl\AZ91_NaCl26.jpg"
filename_list.append(filename_26)
filename_27 = r"C:\Users\Aviva\Desktop\EDS\AZ91\NaCl\AZ91_NaCl\AZ91_NaCl27.jpg"
filename_list.append(filename_27)
filename_28 = r"C:\Users\Aviva\Desktop\EDS\AZ91\NaCl\AZ91_NaCl\AZ91_NaCl28.jpg"
filename_list.append(filename_28)
filename_29 = r"C:\Users\Aviva\Desktop\EDS\AZ91\NaCl\AZ91_NaCl\AZ91_NaCl29.jpg"
filename_list.append(filename_29)
filename_30 = r"C:\Users\Aviva\Desktop\EDS\AZ91\NaCl\AZ91_NaCl\AZ91_NaCl30.jpg"
filename_list.append(filename_30)

filename_31 = r"C:\Users\Aviva\Desktop\EDS\AZ91\NaCl\AZ91_NaCl\AZ91_NaCl31.jpg"
filename_list.append(filename_31)
filename_32 = r"C:\Users\Aviva\Desktop\EDS\AZ91\NaCl\AZ91_NaCl\AZ91_NaCl32.jpg"
filename_list.append(filename_32)
filename_33 = r"C:\Users\Aviva\Desktop\EDS\AZ91\NaCl\AZ91_NaCl\AZ91_NaCl33.jpg"
filename_list.append(filename_33)
filename_34 = r"C:\Users\Aviva\Desktop\EDS\AZ91\NaCl\AZ91_NaCl\AZ91_NaCl34.jpg"
filename_list.append(filename_34)
filename_35 = r"C:\Users\Aviva\Desktop\EDS\AZ91\NaCl\AZ91_NaCl\AZ91_NaCl35.jpg"
filename_list.append(filename_35)
filename_36 = r"C:\Users\Aviva\Desktop\EDS\AZ91\NaCl\AZ91_NaCl\AZ91_NaCl36.jpg"
filename_list.append(filename_36)

# %%
#filter by area
s1= 0
s2 = 100000000
result= []



for file in filename_list:
    
    gray = cv2.imread(file, 0)
    #threshold
    th, threshed = cv2.threshold(gray, 100, 255,cv2.THRESH_BINARY_INV|cv2.THRESH_OTSU)
    #findcontours
    cnts = cv2.findContours(threshed, cv2.RETR_LIST, cv2.CHAIN_APPROX_SIMPLE)[-2]
    
    xcnts = []
    for cnt in cnts:
        if s1<cv2.contourArea(cnt) <s2:
            xcnts.append(cnt)
    result.append(len(xcnts))
#     print("Dots number: {}".format(len(xcnts)))

dataSei = pd.Series(data=result)
df['AZ91_NaCl']=dataSei


#df.to_csv('AM50_40min.csv', index=False)
df
# Out:
#     AM50_before  AM50_Hanks  AM50_NaCl  AZ91_before  AZ91_hanks  AZ91_NaCl
# 0          69.0          68         85           52          81         83
# 1          60.0          78         76           58         112         87
# 2          63.0          76         82           63         107         80
# 3          69.0          60         86           64          98         84
# 4          58.0          88         98           56         107         81
# 5          67.0           0         97           63         106         89
# 6          59.0          73        104           57         101         95
# 7          71.0          69         98           62         108         91
# 8          68.0          86        107           68         108         87
# 9          61.0          89        126           62         117         98
# 10         58.0          84         88           59         110        100
# ...

# %%
#Open a jpg file
filename_list = []

filename_1 = r"C:\Users\Aviva\Desktop\EDS\AZx612\before\AZx612_before\AZx612_before01.jpg"
filename_list.append(filename_1)
filename_2 = r"C:\Users\Aviva\Desktop\EDS\AZx612\before\AZx612_before\AZx612_before02.jpg"
filename_list.append(filename_2)
filename_3 = r"C:\Users\Aviva\Desktop\EDS\AZx612\before\AZx612_before\AZx612_before03.jpg"
filename_list.append(filename_3)
filename_4 = r"C:\Users\Aviva\Desktop\EDS\AZx612\before\AZx612_before\AZx612_before04.jpg"
filename_list.append(filename_4)
filename_5 = r"C:\Users\Aviva\Desktop\EDS\AZx612\before\AZx612_before\AZx612_before05.jpg"
filename_list.append(filename_5)
filename_6 = r"C:\Users\Aviva\Desktop\EDS\AZx612\before\AZx612_before\AZx612_before06.jpg"
filename_list.append(filename_6)

filename_7 = r"C:\Users\Aviva\Desktop\EDS\AZx612\before\AZx612_before\AZx612_before07.jpg"
filename_list.append(filename_7)
filename_8 = r"C:\Users\Aviva\Desktop\EDS\AZx612\before\AZx612_before\AZx612_before08.jpg"
filename_list.append(filename_8)
filename_9 = r"C:\Users\Aviva\Desktop\EDS\AZx612\before\AZx612_before\AZx612_before09.jpg"
filename_list.append(filename_9)
filename_10 = r"C:\Users\Aviva\Desktop\EDS\AZx612\before\AZx612_before\AZx612_before10.jpg"
filename_list.append(filename_10)
filename_11 = r"C:\Users\Aviva\Desktop\EDS\AZx612\before\AZx612_before\AZx612_before11.jpg"
filename_list.append(filename_11)
filename_12 = r"C:\Users\Aviva\Desktop\EDS\AZx612\before\AZx612_before\AZx612_before12.jpg"
filename_list.append(filename_12)

filename_13 = r"C:\Users\Aviva\Desktop\EDS\AZx612\before\AZx612_before\AZx612_before13.jpg"
filename_list.append(filename_13)
filename_14 = r"C:\Users\Aviva\Desktop\EDS\AZx612\before\AZx612_before\AZx612_before14.jpg"
filename_list.append(filename_14)
filename_15 = r"C:\Users\Aviva\Desktop\EDS\AZx612\before\AZx612_before\AZx612_before15.jpg"
filename_list.append(filename_15)
filename_16 = r"C:\Users\Aviva\Desktop\EDS\AZx612\before\AZx612_before\AZx612_before16.jpg"
filename_list.append(filename_16)
filename_17 = r"C:\Users\Aviva\Desktop\EDS\AZx612\before\AZx612_before\AZx612_before17.jpg"
filename_list.append(filename_17)
filename_18 = r"C:\Users\Aviva\Desktop\EDS\AZx612\before\AZx612_before\AZx612_before18.jpg"
filename_list.append(filename_18)

filename_19 = r"C:\Users\Aviva\Desktop\EDS\AZx612\before\AZx612_before\AZx612_before19.jpg"
filename_list.append(filename_19)
filename_20 = r"C:\Users\Aviva\Desktop\EDS\AZx612\before\AZx612_before\AZx612_before20.jpg"
filename_list.append(filename_20)
filename_21 = r"C:\Users\Aviva\Desktop\EDS\AZx612\before\AZx612_before\AZx612_before21.jpg"
filename_list.append(filename_21)
filename_22 = r"C:\Users\Aviva\Desktop\EDS\AZx612\before\AZx612_before\AZx612_before22.jpg"
filename_list.append(filename_22)
filename_23 = r"C:\Users\Aviva\Desktop\EDS\AZx612\before\AZx612_before\AZx612_before23.jpg"
filename_list.append(filename_23)
filename_24 = r"C:\Users\Aviva\Desktop\EDS\AZx612\before\AZx612_before\AZx612_before24.jpg"
filename_list.append(filename_24)

    
filename_25 = r"C:\Users\Aviva\Desktop\EDS\AZx612\before\AZx612_before\AZx612_before25.jpg"
filename_list.append(filename_25)
filename_26 = r"C:\Users\Aviva\Desktop\EDS\AZx612\before\AZx612_before\AZx612_before26.jpg"
filename_list.append(filename_26)
filename_27 = r"C:\Users\Aviva\Desktop\EDS\AZx612\before\AZx612_before\AZx612_before27.jpg"
filename_list.append(filename_27)
filename_28 = r"C:\Users\Aviva\Desktop\EDS\AZx612\before\AZx612_before\AZx612_before28.jpg"
filename_list.append(filename_28)
filename_29 = r"C:\Users\Aviva\Desktop\EDS\AZx612\before\AZx612_before\AZx612_before29.jpg"
filename_list.append(filename_29)
filename_30 = r"C:\Users\Aviva\Desktop\EDS\AZx612\before\AZx612_before\AZx612_before30.jpg"
filename_list.append(filename_30)

filename_31 = r"C:\Users\Aviva\Desktop\EDS\AZx612\before\AZx612_before\AZx612_before31.jpg"
filename_list.append(filename_31)
filename_32 = r"C:\Users\Aviva\Desktop\EDS\AZx612\before\AZx612_before\AZx612_before32.jpg"
filename_list.append(filename_32)
filename_33 = r"C:\Users\Aviva\Desktop\EDS\AZx612\before\AZx612_before\AZx612_before33.jpg"
filename_list.append(filename_33)
filename_34 = r"C:\Users\Aviva\Desktop\EDS\AZx612\before\AZx612_before\AZx612_before34.jpg"
filename_list.append(filename_34)
filename_35 = r"C:\Users\Aviva\Desktop\EDS\AZx612\before\AZx612_before\AZx612_before35.jpg"
filename_list.append(filename_35)
filename_36 = r"C:\Users\Aviva\Desktop\EDS\AZx612\before\AZx612_before\AZx612_before36.jpg"
filename_list.append(filename_36)

# %%
#filter by area
s1= 0
s2 = 100000000
result= []



for file in filename_list:
    
    gray = cv2.imread(file, 0)
    #threshold
    th, threshed = cv2.threshold(gray, 100, 255,cv2.THRESH_BINARY_INV|cv2.THRESH_OTSU)
    #findcontours
    cnts = cv2.findContours(threshed, cv2.RETR_LIST, cv2.CHAIN_APPROX_SIMPLE)[-2]
    
    xcnts = []
    for cnt in cnts:
        if s1<cv2.contourArea(cnt) <s2:
            xcnts.append(cnt)
    result.append(len(xcnts))
#     print("Dots number: {}".format(len(xcnts)))

dataSei = pd.Series(data=result)
df['AZx612_before']=dataSei


#df.to_csv('AM50_40min.csv', index=False)
df
# Out:
#     AM50_before  AM50_Hanks  AM50_NaCl  AZ91_before  AZ91_hanks  AZ91_NaCl  \
# 0          69.0          68         85           52          81         83
# 1          60.0          78         76           58         112         87
# 2          63.0          76         82           63         107         80
# 3          69.0          60         86           64          98         84
# 4          58.0          88         98           56         107         81
# 5          67.0           0         97           63         106         89
# 6          59.0          73        104           57         101         95
# 7          71.0          69         98           62         108         91
# 8          68.0          86        107           68         108         87
# 9          61.0          89        126           62         117         98
# 10         58.0          84         88           59         110        100
# ...

# %%
#Open a jpg file
filename_list = []

filename_1 = r"C:\Users\Aviva\Desktop\EDS\AZx612\Hanks\AZx612_hanks\AZx612_hanks01.jpg"
filename_list.append(filename_1)
filename_2 = r"C:\Users\Aviva\Desktop\EDS\AZx612\Hanks\AZx612_hanks\AZx612_hanks02.jpg"
filename_list.append(filename_2)
filename_3 = r"C:\Users\Aviva\Desktop\EDS\AZx612\Hanks\AZx612_hanks\AZx612_hanks03.jpg"
filename_list.append(filename_3)
filename_4 = r"C:\Users\Aviva\Desktop\EDS\AZx612\Hanks\AZx612_hanks\AZx612_hanks04.jpg"
filename_list.append(filename_4)
filename_5 = r"C:\Users\Aviva\Desktop\EDS\AZx612\Hanks\AZx612_hanks\AZx612_hanks05.jpg"
filename_list.append(filename_5)
filename_6 = r"C:\Users\Aviva\Desktop\EDS\AZx612\Hanks\AZx612_hanks\AZx612_hanks06.jpg"
filename_list.append(filename_6)

filename_7 = r"C:\Users\Aviva\Desktop\EDS\AZx612\Hanks\AZx612_hanks\AZx612_hanks07.jpg"
filename_list.append(filename_7)
filename_8 = r"C:\Users\Aviva\Desktop\EDS\AZx612\Hanks\AZx612_hanks\AZx612_hanks08.jpg"
filename_list.append(filename_8)
filename_9 = r"C:\Users\Aviva\Desktop\EDS\AZx612\Hanks\AZx612_hanks\AZx612_hanks09.jpg"
filename_list.append(filename_9)
filename_10 = r"C:\Users\Aviva\Desktop\EDS\AZx612\Hanks\AZx612_hanks\AZx612_hanks10.jpg"
filename_list.append(filename_10)
filename_11 = r"C:\Users\Aviva\Desktop\EDS\AZx612\Hanks\AZx612_hanks\AZx612_hanks11.jpg"
filename_list.append(filename_11)
filename_12 = r"C:\Users\Aviva\Desktop\EDS\AZx612\Hanks\AZx612_hanks\AZx612_hanks12.jpg"
filename_list.append(filename_12)

filename_13 = r"C:\Users\Aviva\Desktop\EDS\AZx612\Hanks\AZx612_hanks\AZx612_hanks13.jpg"
filename_list.append(filename_13)
filename_14 = r"C:\Users\Aviva\Desktop\EDS\AZx612\Hanks\AZx612_hanks\AZx612_hanks14.jpg"
filename_list.append(filename_14)
filename_15 = r"C:\Users\Aviva\Desktop\EDS\AZx612\Hanks\AZx612_hanks\AZx612_hanks15.jpg"
filename_list.append(filename_15)
filename_16 = r"C:\Users\Aviva\Desktop\EDS\AZx612\Hanks\AZx612_hanks\AZx612_hanks16.jpg"
filename_list.append(filename_16)
filename_17 = r"C:\Users\Aviva\Desktop\EDS\AZx612\Hanks\AZx612_hanks\AZx612_hanks17.jpg"
filename_list.append(filename_17)
filename_18 = r"C:\Users\Aviva\Desktop\EDS\AZx612\Hanks\AZx612_hanks\AZx612_hanks18.jpg"
filename_list.append(filename_18)

filename_19 = r"C:\Users\Aviva\Desktop\EDS\AZx612\Hanks\AZx612_hanks\AZx612_hanks19.jpg"
filename_list.append(filename_19)
filename_20 = r"C:\Users\Aviva\Desktop\EDS\AZx612\Hanks\AZx612_hanks\AZx612_hanks20.jpg"
filename_list.append(filename_20)
filename_21 = r"C:\Users\Aviva\Desktop\EDS\AZx612\Hanks\AZx612_hanks\AZx612_hanks21.jpg"
filename_list.append(filename_21)
filename_22 = r"C:\Users\Aviva\Desktop\EDS\AZx612\Hanks\AZx612_hanks\AZx612_hanks22.jpg"
filename_list.append(filename_22)
filename_23 = r"C:\Users\Aviva\Desktop\EDS\AZx612\Hanks\AZx612_hanks\AZx612_hanks23.jpg"
filename_list.append(filename_23)
filename_24 = r"C:\Users\Aviva\Desktop\EDS\AZx612\Hanks\AZx612_hanks\AZx612_hanks24.jpg"
filename_list.append(filename_24)

    
filename_25 = r"C:\Users\Aviva\Desktop\EDS\AZx612\Hanks\AZx612_hanks\AZx612_hanks25.jpg"
filename_list.append(filename_25)
filename_26 = r"C:\Users\Aviva\Desktop\EDS\AZx612\Hanks\AZx612_hanks\AZx612_hanks26.jpg"
filename_list.append(filename_26)
filename_27 = r"C:\Users\Aviva\Desktop\EDS\AZx612\Hanks\AZx612_hanks\AZx612_hanks27.jpg"
filename_list.append(filename_27)
filename_28 = r"C:\Users\Aviva\Desktop\EDS\AZx612\Hanks\AZx612_hanks\AZx612_hanks28.jpg"
filename_list.append(filename_28)
filename_29 = r"C:\Users\Aviva\Desktop\EDS\AZx612\Hanks\AZx612_hanks\AZx612_hanks29.jpg"
filename_list.append(filename_29)
filename_30 = r"C:\Users\Aviva\Desktop\EDS\AZx612\Hanks\AZx612_hanks\AZx612_hanks30.jpg"
filename_list.append(filename_30)

filename_31 = r"C:\Users\Aviva\Desktop\EDS\AZx612\Hanks\AZx612_hanks\AZx612_hanks31.jpg"
filename_list.append(filename_31)
filename_32 = r"C:\Users\Aviva\Desktop\EDS\AZx612\Hanks\AZx612_hanks\AZx612_hanks32.jpg"
filename_list.append(filename_32)
filename_33 = r"C:\Users\Aviva\Desktop\EDS\AZx612\Hanks\AZx612_hanks\AZx612_hanks33.jpg"
filename_list.append(filename_33)
filename_34 = r"C:\Users\Aviva\Desktop\EDS\AZx612\Hanks\AZx612_hanks\AZx612_hanks34.jpg"
filename_list.append(filename_34)
filename_35 = r"C:\Users\Aviva\Desktop\EDS\AZx612\Hanks\AZx612_hanks\AZx612_hanks35.jpg"
filename_list.append(filename_35)
filename_36 = r"C:\Users\Aviva\Desktop\EDS\AZx612\Hanks\AZx612_hanks\AZx612_hanks36.jpg"
filename_list.append(filename_36)

# %%
#filter by area
s1= 0
s2 = 100000000
result= []



for file in filename_list:
    
    gray = cv2.imread(file, 0)
    #threshold
    th, threshed = cv2.threshold(gray, 100, 255,cv2.THRESH_BINARY_INV|cv2.THRESH_OTSU)
    #findcontours
    cnts = cv2.findContours(threshed, cv2.RETR_LIST, cv2.CHAIN_APPROX_SIMPLE)[-2]
    
    xcnts = []
    for cnt in cnts:
        if s1<cv2.contourArea(cnt) <s2:
            xcnts.append(cnt)
    result.append(len(xcnts))
#     print("Dots number: {}".format(len(xcnts)))

dataSei = pd.Series(data=result)
df['AZx612_hanks']=dataSei


#df.to_csv('AM50_40min.csv', index=False)
df
# Out:
#     AM50_before  AM50_Hanks  AM50_NaCl  AZ91_before  AZ91_hanks  AZ91_NaCl  \
# 0          69.0          68         85           52          81         83
# 1          60.0          78         76           58         112         87
# 2          63.0          76         82           63         107         80
# 3          69.0          60         86           64          98         84
# 4          58.0          88         98           56         107         81
# 5          67.0           0         97           63         106         89
# 6          59.0          73        104           57         101         95
# 7          71.0          69         98           62         108         91
# 8          68.0          86        107           68         108         87
# 9          61.0          89        126           62         117         98
# 10         58.0          84         88           59         110        100
# ...

# %%
#Open a jpg file
filename_list = []

filename_1 = r"C:\Users\Aviva\Desktop\EDS\AZx612\NaCl\AZx612_NaCl\AZx612_NaCl01.jpg"
filename_list.append(filename_1)
filename_2 = r"C:\Users\Aviva\Desktop\EDS\AZx612\NaCl\AZx612_NaCl\AZx612_NaCl02.jpg"
filename_list.append(filename_2)
filename_3 = r"C:\Users\Aviva\Desktop\EDS\AZx612\NaCl\AZx612_NaCl\AZx612_NaCl03.jpg"
filename_list.append(filename_3)
filename_4 = r"C:\Users\Aviva\Desktop\EDS\AZx612\NaCl\AZx612_NaCl\AZx612_NaCl04.jpg"
filename_list.append(filename_4)
filename_5 = r"C:\Users\Aviva\Desktop\EDS\AZx612\NaCl\AZx612_NaCl\AZx612_NaCl05.jpg"
filename_list.append(filename_5)
filename_6 = r"C:\Users\Aviva\Desktop\EDS\AZx612\NaCl\AZx612_NaCl\AZx612_NaCl06.jpg"
filename_list.append(filename_6)

filename_7 = r"C:\Users\Aviva\Desktop\EDS\AZx612\NaCl\AZx612_NaCl\AZx612_NaCl07.jpg"
filename_list.append(filename_7)
filename_8 = r"C:\Users\Aviva\Desktop\EDS\AZx612\NaCl\AZx612_NaCl\AZx612_NaCl08.jpg"
filename_list.append(filename_8)
filename_9 = r"C:\Users\Aviva\Desktop\EDS\AZx612\NaCl\AZx612_NaCl\AZx612_NaCl09.jpg"
filename_list.append(filename_9)
filename_10 = r"C:\Users\Aviva\Desktop\EDS\AZx612\NaCl\AZx612_NaCl\AZx612_NaCl10.jpg"
filename_list.append(filename_10)
filename_11 = r"C:\Users\Aviva\Desktop\EDS\AZx612\NaCl\AZx612_NaCl\AZx612_NaCl11.jpg"
filename_list.append(filename_11)
filename_12 = r"C:\Users\Aviva\Desktop\EDS\AZx612\NaCl\AZx612_NaCl\AZx612_NaCl12.jpg"
filename_list.append(filename_12)

filename_13 = r"C:\Users\Aviva\Desktop\EDS\AZx612\NaCl\AZx612_NaCl\AZx612_NaCl13.jpg"
filename_list.append(filename_13)
filename_14 = r"C:\Users\Aviva\Desktop\EDS\AZx612\NaCl\AZx612_NaCl\AZx612_NaCl14.jpg"
filename_list.append(filename_14)
filename_15 = r"C:\Users\Aviva\Desktop\EDS\AZx612\NaCl\AZx612_NaCl\AZx612_NaCl15.jpg"
filename_list.append(filename_15)
filename_16 = r"C:\Users\Aviva\Desktop\EDS\AZx612\NaCl\AZx612_NaCl\AZx612_NaCl16.jpg"
filename_list.append(filename_16)
filename_17 = r"C:\Users\Aviva\Desktop\EDS\AZx612\NaCl\AZx612_NaCl\AZx612_NaCl17.jpg"
filename_list.append(filename_17)
filename_18 = r"C:\Users\Aviva\Desktop\EDS\AZx612\NaCl\AZx612_NaCl\AZx612_NaCl18.jpg"
filename_list.append(filename_18)

filename_19 = r"C:\Users\Aviva\Desktop\EDS\AZx612\NaCl\AZx612_NaCl\AZx612_NaCl19.jpg"
filename_list.append(filename_19)
filename_20 = r"C:\Users\Aviva\Desktop\EDS\AZx612\NaCl\AZx612_NaCl\AZx612_NaCl20.jpg"
filename_list.append(filename_20)
filename_21 = r"C:\Users\Aviva\Desktop\EDS\AZx612\NaCl\AZx612_NaCl\AZx612_NaCl21.jpg"
filename_list.append(filename_21)
filename_22 = r"C:\Users\Aviva\Desktop\EDS\AZx612\NaCl\AZx612_NaCl\AZx612_NaCl22.jpg"
filename_list.append(filename_22)
filename_23 = r"C:\Users\Aviva\Desktop\EDS\AZx612\NaCl\AZx612_NaCl\AZx612_NaCl23.jpg"
filename_list.append(filename_23)
filename_24 = r"C:\Users\Aviva\Desktop\EDS\AZx612\NaCl\AZx612_NaCl\AZx612_NaCl24.jpg"
filename_list.append(filename_24)

    
filename_25 = r"C:\Users\Aviva\Desktop\EDS\AZx612\NaCl\AZx612_NaCl\AZx612_NaCl25.jpg"
filename_list.append(filename_25)
filename_26 = r"C:\Users\Aviva\Desktop\EDS\AZx612\NaCl\AZx612_NaCl\AZx612_NaCl26.jpg"
filename_list.append(filename_26)
filename_27 = r"C:\Users\Aviva\Desktop\EDS\AZx612\NaCl\AZx612_NaCl\AZx612_NaCl27.jpg"
filename_list.append(filename_27)
filename_28 = r"C:\Users\Aviva\Desktop\EDS\AZx612\NaCl\AZx612_NaCl\AZx612_NaCl28.jpg"
filename_list.append(filename_28)
filename_29 = r"C:\Users\Aviva\Desktop\EDS\AZx612\NaCl\AZx612_NaCl\AZx612_NaCl29.jpg"
filename_list.append(filename_29)
filename_30 = r"C:\Users\Aviva\Desktop\EDS\AZx612\NaCl\AZx612_NaCl\AZx612_NaCl30.jpg"
filename_list.append(filename_30)

filename_31 = r"C:\Users\Aviva\Desktop\EDS\AZx612\NaCl\AZx612_NaCl\AZx612_NaCl31.jpg"
filename_list.append(filename_31)
filename_32 = r"C:\Users\Aviva\Desktop\EDS\AZx612\NaCl\AZx612_NaCl\AZx612_NaCl32.jpg"
filename_list.append(filename_32)
filename_33 = r"C:\Users\Aviva\Desktop\EDS\AZx612\NaCl\AZx612_NaCl\AZx612_NaCl33.jpg"
filename_list.append(filename_33)
filename_34 = r"C:\Users\Aviva\Desktop\EDS\AZx612\NaCl\AZx612_NaCl\AZx612_NaCl34.jpg"
filename_list.append(filename_34)
filename_35 = r"C:\Users\Aviva\Desktop\EDS\AZx612\NaCl\AZx612_NaCl\AZx612_NaCl35.jpg"
filename_list.append(filename_35)
filename_36 = r"C:\Users\Aviva\Desktop\EDS\AZx612\NaCl\AZx612_NaCl\AZx612_NaCl36.jpg"
filename_list.append(filename_36)

# %%
#filter by area
s1= 0
s2 = 100000000
result= []



for file in filename_list:
    
    gray = cv2.imread(file, 0)
    #threshold
    th, threshed = cv2.threshold(gray, 100, 255,cv2.THRESH_BINARY_INV|cv2.THRESH_OTSU)
    #findcontours
    cnts = cv2.findContours(threshed, cv2.RETR_LIST, cv2.CHAIN_APPROX_SIMPLE)[-2]
    
    xcnts = []
    for cnt in cnts:
        if s1<cv2.contourArea(cnt) <s2:
            xcnts.append(cnt)
    result.append(len(xcnts))
#     print("Dots number: {}".format(len(xcnts)))

dataSei = pd.Series(data=result)
df['AZx612_NaCl']=dataSei


#df.to_csv('AM50_40min.csv', index=False)
df
# Out:
#     AM50_before  AM50_Hanks  AM50_NaCl  AZ91_before  AZ91_hanks  AZ91_NaCl  \
# 0          69.0          68         85           52          81         83
# 1          60.0          78         76           58         112         87
# 2          63.0          76         82           63         107         80
# 3          69.0          60         86           64          98         84
# 4          58.0          88         98           56         107         81
# 5          67.0           0         97           63         106         89
# 6          59.0          73        104           57         101         95
# 7          71.0          69         98           62         108         91
# 8          68.0          86        107           68         108         87
# 9          61.0          89        126           62         117         98
# 10         58.0          84         88           59         110        100
# ...

# %%
describe = df.describe()
describe
# Out:
#        AM50_before  AM50_Hanks   AM50_NaCl  AZ91_before  AZ91_hanks  \
# count    36.000000   36.000000   36.000000    36.000000   36.000000
# mean     68.222222   85.555556  104.027778    65.583333  111.277778
# std       9.535231   18.410315   14.427129     8.405355   11.149916
# min      54.000000    0.000000   76.000000    51.000000   81.000000
# 25%      61.000000   81.000000   93.750000    60.750000  106.750000
# 50%      68.500000   88.000000  103.500000    63.000000  111.500000
# 75%      72.000000   96.750000  116.000000    72.000000  118.250000
# max      95.000000  109.000000  130.000000    90.000000  135.000000
#
#         AZ91_NaCl  AZx612_before  AZx612_hanks  AZx612_NaCl
# count   36.000000      36.000000     36.000000    36.000000
# mean    98.277778      72.083333    101.500000    82.944444
# std     10.177317       9.586821     14.612128    10.474307
# min     80.000000      51.000000     81.000000    64.000000
# ...

# %%
# std = pd.DataFrame(columns=df.columns)
# stdList = []

# for column in df.columns:
#     stdList.append(df[column].std)

# %%
df.to_csv(r'C:\Users\Aviva\Desktop\EDS\results.csv', index = False)

# %%
# sns.lineplot(x="AZ91_before", y="AZ91_before", data=describe,)
# plt.show()
